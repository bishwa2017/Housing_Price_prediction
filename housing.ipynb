# %%
import pandas as pd
import numpy as np

# %%
test_data=pd.read_csv('Housing.test.csv')
test_data
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %%
train_data=pd.read_csv("housing.train.csv")
train_data
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %% [markdown]
# 1st we will go with train data

# %% [markdown]
# # Checking Null Value¶¶

# %%
train_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# # Checking Datatypes

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
import seaborn as sns

# %%
sns.heatmap(train_data.isnull())
# Out:
# <AxesSubplot:>

# %%
train_data['LotFrontage']=train_data['LotFrontage'].replace(np.NAN,train_data['LotFrontage'].mean())
train_data['GarageYrBlt']=train_data['GarageYrBlt'].replace(np.NAN,train_data['GarageYrBlt'].mean())

# %%
train_data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
test_data.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %%
test_data['LotFrontage']=test_data['LotFrontage'].replace(np.NAN,test_data['LotFrontage'].mean())
test_data['GarageYrBlt']=test_data['GarageYrBlt'].replace(np.NAN,test_data['GarageYrBlt'].mean())

# %%
test_data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 80, dtype: int64

# %%
test_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object

# %% [markdown]
# # Eda Procedure

# %%
sns.catplot(x="Id",y="SalePrice",data=train_data)

# %%
sns.regplot(x="Id",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='Id', ylabel='SalePrice'>

# %%
sns.scatterplot(x="Id",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='Id', ylabel='SalePrice'>

# %%
sns.boxplot(x="Id",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='Id', ylabel='SalePrice'>

# %%
sns.boxplot(x="LotArea",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.scatterplot(x="LotArea",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.regplot(x="LotArea",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.catplot(x="LotArea",y="SalePrice",data=train_data)

# %%
sns.boxplot(x="SaleCondition",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %%
sns.scatterplot(x="SaleCondition",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %%
sns.scatterplot(x="SaleType",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='SaleType', ylabel='SalePrice'>

# %%
sns.scatterplot(x="YrSold",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='SalePrice'>

# %%
sns.scatterplot(x="PoolArea",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='PoolArea', ylabel='SalePrice'>

# %%
sns.boxplot(x="PoolArea",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='PoolArea', ylabel='SalePrice'>

# %%
sns.boxplot(x="ScreenPorch",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='ScreenPorch', ylabel='SalePrice'>

# %%
sns.scatterplot(x="ScreenPorch",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='ScreenPorch', ylabel='SalePrice'>

# %%
sns.scatterplot(x="MSSubClass",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %%
sns.boxplot(x="MSSubClass",y="SalePrice",data=train_data)
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %%
train_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1168.000000  1168.000000  1168.000000    1168.000000  1168.000000
# mean    724.136130    56.767979    70.988470   10484.749144     6.104452
# std     416.159877    41.940650    22.437056    8957.442311     1.390153
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     360.500000    20.000000    60.000000    7621.500000     5.000000
# 50%     714.500000    50.000000    70.988470    9522.500000     6.000000
# 75%    1079.500000    70.000000    79.250000   11515.500000     7.000000
# max    1460.000000   190.000000   313.000000  164660.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1168.000000  1168.000000   1168.000000  1161.000000  1168.000000  ...
# mean      5.595890  1970.930651   1984.758562   102.310078   444.726027  ...
# std       1.124343    30.145255     20.785185   182.595606   462.664785  ...
# ...

# %%
test_data.describe()
# Out:
#                 Id  MSSubClass  LotFrontage        LotArea  OverallQual  \
# count   292.000000  292.000000   292.000000     292.000000   292.000000
# mean    755.955479   57.414384    66.425101   10645.143836     6.078767
# std     442.565228   43.780649    19.975962   13330.669795     1.356147
# min       6.000000   20.000000    21.000000    1526.000000     3.000000
# 25%     377.750000   20.000000    57.750000    7200.000000     5.000000
# 50%     778.000000   50.000000    66.425101    9200.000000     6.000000
# 75%    1152.250000   70.000000    76.000000   11658.750000     7.000000
# max    1456.000000  190.000000   150.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count   292.000000   292.000000    292.000000   291.000000   292.000000  ...
# mean      5.493151  1972.616438   1985.294521   109.171821   439.294521  ...
# std       1.063267    30.447016     20.105792   175.030021   429.559675  ...
# ...

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
lencode=LabelEncoder()
train_data['SaleType']=lencode.fit_transform(train_data['SaleType'])
train_data['SaleCondition']=lencode.fit_transform(train_data['SaleCondition'])
train_data['Fence']=lencode.fit_transform(train_data['Fence'])
train_data['PoolQC']=lencode.fit_transform(train_data['PoolQC'])
train_data['MiscFeature']=lencode.fit_transform(train_data['MiscFeature'])
train_data['Alley']=lencode.fit_transform(train_data['Alley'])
train_data['MSZoning']=lencode.fit_transform(train_data['MSZoning'])
train_data['LotFrontage']=lencode.fit_transform(train_data['LotFrontage'])
train_data['GarageFinish']=lencode.fit_transform(train_data['GarageFinish'])
train_data['GarageCond']=lencode.fit_transform(train_data['GarageCond'])
train_data['GarageQual']=lencode.fit_transform(train_data['GarageQual'])
train_data['GarageType']=lencode.fit_transform(train_data['GarageType'])
train_data['FireplaceQu']=lencode.fit_transform(train_data['FireplaceQu'])
train_data['Street']=lencode.fit_transform(train_data['Street'])
train_data['LotShape']=lencode.fit_transform(train_data['LotShape'])
train_data['PavedDrive']=lencode.fit_transform(train_data['PavedDrive'])
train_data['Functional']=lencode.fit_transform(train_data['Functional'])
train_data['KitchenQual']=lencode.fit_transform(train_data['KitchenQual'])
train_data['Electrical']=lencode.fit_transform(train_data['Electrical'])
train_data['CentralAir']=lencode.fit_transform(train_data['CentralAir'])
train_data['HeatingQC']=lencode.fit_transform(train_data['HeatingQC'])
train_data['Heating']=lencode.fit_transform(train_data['Heating'])
train_data['BsmtQual']=lencode.fit_transform(train_data['BsmtQual'])
train_data['ExterQual']=lencode.fit_transform(train_data['ExterQual'])
train_data['ExterCond']=lencode.fit_transform(train_data['ExterCond'])
train_data['BsmtCond']=lencode.fit_transform(train_data['BsmtCond'])
train_data['Foundation']=lencode.fit_transform(train_data['Foundation'])
train_data['BsmtExposure']=lencode.fit_transform(train_data['BsmtExposure'])
train_data['BsmtFinType1']=lencode.fit_transform(train_data['BsmtFinType1'])
train_data['BsmtFinType2']=lencode.fit_transform(train_data['BsmtFinType2'])
train_data['HouseStyle']=lencode.fit_transform(train_data['HouseStyle'])
train_data['BldgType']=lencode.fit_transform(train_data['BldgType'])
train_data['Condition2']=lencode.fit_transform(train_data['Condition2'])
train_data['Condition1']=lencode.fit_transform(train_data['Condition1'])
train_data['Neighborhood']=lencode.fit_transform(train_data['Neighborhood'])
train_data['LandSlope']=lencode.fit_transform(train_data['LandSlope'])
train_data['LotConfig']=lencode.fit_transform(train_data['LotConfig'])
train_data['Utilities']=lencode.fit_transform(train_data['Utilities'])
train_data['LandContour']=lencode.fit_transform(train_data['LandContour'])
train_data['RoofStyle']=lencode.fit_transform(train_data['RoofStyle'])
train_data['RoofMatl']=lencode.fit_transform(train_data['RoofMatl'])
train_data['Exterior1st']=lencode.fit_transform(train_data['Exterior1st'])
train_data['Exterior2nd']=lencode.fit_transform(train_data['Exterior2nd'])
train_data['MasVnrType']=lencode.fit_transform(train_data['MasVnrType'])
train_data['CentralAir']=lencode.fit_transform(train_data['CentralAir'])
train_data.dtypes
# Out:
# Id               int64
# MSSubClass       int64
# MSZoning         int32
# LotFrontage      int64
# LotArea          int64
#                  ...
# MoSold           int64
# YrSold           int64
# SaleType         int32
# SaleCondition    int32
# SalePrice        int64
# Length: 81, dtype: object

# %%
train_data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
test_data['SaleType']=lencode.fit_transform(test_data['SaleType'])
test_data['SaleCondition']=lencode.fit_transform(test_data['SaleCondition'])
test_data['Fence']=lencode.fit_transform(test_data['Fence'])
test_data['PoolQC']=lencode.fit_transform(test_data['PoolQC'])
test_data['MiscFeature']=lencode.fit_transform(test_data['MiscFeature'])
test_data['Alley']=lencode.fit_transform(test_data['Alley'])
test_data['MSZoning']=lencode.fit_transform(test_data['MSZoning'])
test_data['LotFrontage']=lencode.fit_transform(test_data['LotFrontage'])
test_data['GarageFinish']=lencode.fit_transform(test_data['GarageFinish'])
test_data['GarageCond']=lencode.fit_transform(test_data['GarageCond'])
test_data['GarageQual']=lencode.fit_transform(test_data['GarageQual'])
test_data['GarageType']=lencode.fit_transform(test_data['GarageType'])
test_data['FireplaceQu']=lencode.fit_transform(test_data['FireplaceQu'])
test_data['Street']=lencode.fit_transform(test_data['Street'])
test_data['LotShape']=lencode.fit_transform(test_data['LotShape'])
test_data['PavedDrive']=lencode.fit_transform(test_data['PavedDrive'])
test_data['Functional']=lencode.fit_transform(test_data['Functional'])
test_data['KitchenQual']=lencode.fit_transform(test_data['KitchenQual'])
test_data['Electrical']=lencode.fit_transform(test_data['Electrical'])
test_data['CentralAir']=lencode.fit_transform(test_data['CentralAir'])
test_data['HeatingQC']=lencode.fit_transform(test_data['HeatingQC'])
test_data['Heating']=lencode.fit_transform(test_data['Heating'])
test_data['BsmtQual']=lencode.fit_transform(test_data['BsmtQual'])
test_data['ExterQual']=lencode.fit_transform(test_data['ExterQual'])
test_data['ExterCond']=lencode.fit_transform(test_data['ExterCond'])
test_data['BsmtCond']=lencode.fit_transform(test_data['BsmtCond'])
test_data['Foundation']=lencode.fit_transform(test_data['Foundation'])
test_data['BsmtExposure']=lencode.fit_transform(test_data['BsmtExposure'])
test_data['BsmtFinType1']=lencode.fit_transform(test_data['BsmtFinType1'])
test_data['BsmtFinType2']=lencode.fit_transform(test_data['BsmtFinType2'])
test_data['HouseStyle']=lencode.fit_transform(test_data['HouseStyle'])
test_data['BldgType']=lencode.fit_transform(test_data['BldgType'])
test_data['Condition2']=lencode.fit_transform(test_data['Condition2'])
test_data['Condition1']=lencode.fit_transform(test_data['Condition1'])
test_data['Neighborhood']=lencode.fit_transform(test_data['Neighborhood'])
test_data['LandSlope']=lencode.fit_transform(test_data['LandSlope'])
test_data['LotConfig']=lencode.fit_transform(test_data['LotConfig'])
test_data['Utilities']=lencode.fit_transform(test_data['Utilities'])
test_data['LandContour']=lencode.fit_transform(test_data['LandContour'])
test_data['RoofStyle']=lencode.fit_transform(test_data['RoofStyle'])
test_data['RoofMatl']=lencode.fit_transform(test_data['RoofMatl'])
test_data['Exterior1st']=lencode.fit_transform(test_data['Exterior1st'])
test_data['Exterior2nd']=lencode.fit_transform(test_data['Exterior2nd'])
test_data['MasVnrType']=lencode.fit_transform(test_data['MasVnrType'])
test_data['CentralAir']=lencode.fit_transform(test_data['CentralAir'])
test_data.dtypes
# Out:
# Id               int64
# MSSubClass       int64
# MSZoning         int32
# LotFrontage      int64
# LotArea          int64
#                  ...
# MiscVal          int64
# MoSold           int64
# YrSold           int64
# SaleType         int32
# SaleCondition    int32
# Length: 80, dtype: object

# %%
for i in train_data.columns:
    sns.displot(train_data[i])
# Out:
# C:\Users\bisue\anaconda2\lib\site-packages\seaborn\axisgrid.py:392: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)

# %%
train_data['Alley']=train_data['Alley'].replace(np.NAN,train_data['Alley'].mean())
train_data['MiscFeature']=train_data['MiscFeature'].replace(np.NAN,train_data['MiscFeature'].mean())
train_data['Fence']=train_data['Fence'].replace(np.NAN,train_data['Fence'].mean())
train_data['PoolQC']=train_data['Fence'].replace(np.NAN,train_data['PoolQC'].mean())
train_data['MasVnrType']=train_data['MasVnrType'].replace(np.NAN,train_data['MasVnrType'].mean())
train_data['MasVnrArea']=train_data['MasVnrArea'].replace(np.NAN,train_data['MasVnrArea'].mean())
train_data['BsmtQual']=train_data['BsmtQual'].replace(np.NAN,train_data['BsmtQual'].mean())
train_data['BsmtCond']=train_data['BsmtCond'].replace(np.NAN,train_data['BsmtCond'].mean())
train_data['BsmtExposure']=train_data['BsmtExposure'].replace(np.NAN,train_data['BsmtExposure'].mean())
train_data['BsmtFinType1']=train_data['BsmtFinType1'].replace(np.NAN,train_data['BsmtFinType1'].mean())
train_data['BsmtFinType2']=train_data['BsmtFinType2'].replace(np.NAN,train_data['BsmtFinType2'].mean())
train_data['FireplaceQu']=train_data['FireplaceQu'].replace(np.NAN,train_data['FireplaceQu'].mean())
train_data['GarageType']=train_data['GarageType'].replace(np.NAN,train_data['GarageType'].mean())
train_data['GarageYrBlt']=train_data['GarageYrBlt'].replace(np.NAN,train_data['GarageYrBlt'].mean())
train_data['GarageFinish']=train_data['GarageFinish'].replace(np.NAN,train_data['GarageFinish'].mean())
train_data['GarageCars']=train_data['GarageCars'].replace(np.NAN,train_data['GarageCars'].mean())
train_data['GarageArea']=train_data['GarageArea'].replace(np.NAN,train_data['GarageArea'].mean())
train_data['GarageQual']=train_data['GarageQual'].replace(np.NAN,train_data['GarageQual'].mean())
train_data['GarageCond']=train_data['GarageCond'].replace(np.NAN,train_data['GarageCond'].mean())

# %%
test_data['Alley']=test_data['Alley'].replace(np.NAN,test_data['Alley'].mean())
test_data['MiscFeature']=test_data['MiscFeature'].replace(np.NAN,test_data['MiscFeature'].mean())
test_data['Fence']=train_data['Fence'].replace(np.NAN,test_data['Fence'].mean())
test_data['PoolQC']=test_data['Fence'].replace(np.NAN,test_data['PoolQC'].mean())
test_data['MasVnrType']=test_data['MasVnrType'].replace(np.NAN,test_data['MasVnrType'].mean())
test_data['MasVnrArea']=test_data['MasVnrArea'].replace(np.NAN,test_data['MasVnrArea'].mean())
test_data['BsmtQual']=test_data['BsmtQual'].replace(np.NAN,test_data['BsmtQual'].mean())
test_data['BsmtCond']=test_data['BsmtCond'].replace(np.NAN,test_data['BsmtCond'].mean())
test_data['BsmtExposure']=test_data['BsmtExposure'].replace(np.NAN,test_data['BsmtExposure'].mean())
test_data['BsmtFinType1']=test_data['BsmtFinType1'].replace(np.NAN,test_data['BsmtFinType1'].mean())
test_data['BsmtFinType2']=test_data['BsmtFinType2'].replace(np.NAN,test_data['BsmtFinType2'].mean())
test_data['FireplaceQu']=test_data['FireplaceQu'].replace(np.NAN,test_data['FireplaceQu'].mean())
test_data['GarageType']=test_data['GarageType'].replace(np.NAN,test_data['GarageType'].mean())
test_data['GarageYrBlt']=test_data['GarageYrBlt'].replace(np.NAN,test_data['GarageYrBlt'].mean())
test_data['GarageFinish']=test_data['GarageFinish'].replace(np.NAN,test_data['GarageFinish'].mean())
test_data['GarageCars']=test_data['GarageCars'].replace(np.NAN,test_data['GarageCars'].mean())
test_data['GarageArea']=test_data['GarageArea'].replace(np.NAN,test_data['GarageArea'].mean())
test_data['GarageQual']=test_data['GarageQual'].replace(np.NAN,test_data['GarageQual'].mean())
test_data['GarageCond']=test_data['GarageCond'].replace(np.NAN,test_data['GarageCond'].mean())

# %%
test_data
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     337          20         2           48    14157       1      2
# 1    1018         120         2           31     5814       1      2
# 2     929          20         2           31    11838       1      2
# 3    1148          70         2           40    12000       1      2
# 4    1227          60         2           48    14598       1      2
# ..    ...         ...       ...          ...      ...     ...    ...
# 287    83          20         2           43    10206       1      2
# 288  1048          20         2           21     9245       1      2
# 289    17          20         2           31    11241       1      2
# 290   523          50         3           16     5000       1      2
# 291  1379         160         3            0     1953       1      2
#
#      LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
train_data
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     127         120         3           41     4928       1      2
# 1     889          20         3           66    15865       1      2
# 2     793          60         3           63     9920       1      2
# 3     110          20         3           76    11751       1      2
# 4     422          20         3           41    16635       1      2
# ...   ...         ...       ...          ...      ...     ...    ...
# 1163  289          20         3           41     9819       1      2
# 1164  554          20         3           37     8777       1      2
# 1165  196         160         3            1     2280       1      2
# 1166   31          70         0           20     8500       1      1
# 1167  617          60         3           41     7861       1      2
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
for i in test_data.columns:
    if test_data[i].dtypes=="object":
        test_data[i]=enc.fit_transform(test_data[i].values.reshape(-1,1))

# %%
for i in train_data.columns:
    if train_data[i].dtypes=="object":
        train_data[i]=enc.fit_transform(train_data[i].values.reshape(-1,1))

# %%
for i in train_data.columns:
    sns.boxplot(train_data[i])
# Out:
# C:\Users\bisue\anaconda2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bisue\anaconda2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bisue\anaconda2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in train_data.columns:
    sns.countplot(train_data[i])
# Out:
# C:\Users\bisue\anaconda2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bisue\anaconda2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bisue\anaconda2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
train_data.skew()
# Out:
# Id                0.026526
# MSSubClass        1.422019
# MSZoning         -1.796785
# LotFrontage       0.471005
# LotArea          10.659285
#                    ...
# MoSold            0.220979
# YrSold            0.115765
# SaleType         -3.660513
# SaleCondition    -2.671829
# SalePrice         1.953878
# Length: 81, dtype: float64

# %%
train_data.shape
# Out:
# (1168, 81)

# %%
train_data.corr()
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.004259  0.009307    -0.025295 -0.029212
# MSSubClass     0.004259    1.000000  0.007478    -0.367727 -0.124151
# MSZoning       0.009307    0.007478  1.000000    -0.079477 -0.023328
# LotFrontage   -0.025295   -0.367727 -0.079477     1.000000  0.271121
# LotArea       -0.029212   -0.124151 -0.023328     0.271121  1.000000
# ...                 ...         ...       ...          ...       ...
# MoSold         0.023479   -0.016015 -0.051646     0.027468  0.015141
# YrSold        -0.008853   -0.038595 -0.004964    -0.004527 -0.035399
# SaleType       0.024384    0.035050  0.079854    -0.042208  0.005421
# SaleCondition -0.014726   -0.028981  0.004501     0.072508  0.034236
# SalePrice     -0.023897   -0.060775 -0.133221     0.361572  0.249499
#
#                  Street     Alley  LotShape  LandContour  Utilities  ...  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(22,7))
sns.heatmap(train_data.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(train_data.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(train_data.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # features and Target

# %%
x1=train_data.drop("SalePrice",axis=1)
x2=test_data
y=train_data['SalePrice']

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
scale=StandardScaler()
x1=scale.fit_transform(x1)
x1
# Out:
# array([[-1.43548658,  1.50830058, -0.02164599, ..., -0.60548713,
#          0.33003329,  0.20793187],
#        [ 0.39632483, -0.87704243, -0.02164599, ..., -0.60548713,
#          0.33003329,  0.20793187],
#        [ 0.16554544,  0.07709478, -0.02164599, ..., -0.60548713,
#          0.33003329,  0.20793187],
#        ...,
#        [-1.26961389,  2.46243779, -0.02164599, ...,  0.8992128 ,
#          0.33003329,  0.20793187],
#        [-1.66626597,  0.31562908, -4.76211672, ...,  0.14686284,
#          0.33003329,  0.20793187],
#        [-0.25755011,  0.07709478, -0.02164599, ..., -1.3578371 ,
#          0.33003329,  0.20793187]])

# %%
scale=StandardScaler()
x2=scale.fit_transform(x2)
x2
# Out:
# array([[-0.94827766, -0.85605433, -0.28700579, ..., -0.65090813,
#          0.23029007,  0.14865423],
#        [ 0.59312021,  1.43198105, -0.28700579, ...,  0.86355541,
#         -6.49418003, -3.32390858],
#        [ 0.39167468, -0.85605433, -0.28700579, ...,  0.86355541,
#          0.23029007,  0.14865423],
#        ...,
#        [-1.67257621, -0.85605433, -0.28700579, ...,  1.62078718,
#          0.23029007,  0.14865423],
#        [-0.52727912, -0.16964372,  1.80813647, ..., -1.4081399 ,
#          0.23029007,  0.14865423],
#        [ 1.41021953,  2.3471952 ,  1.80813647, ..., -1.4081399 ,
#          0.23029007,  0.14865423]])

# %%
x1train,x1test,ytrain,ytest=train_test_split(x1,y,test_size=0.30,random_state=55)

# %%
lr=LinearRegression()
lr.fit(x1train,ytrain)
lr.coef_
# Out:
# array([-6.99847549e+02, -5.32109209e+03,  4.66552590e+01,  2.45186322e+03,
#        -1.23724317e+03,  1.49543986e+03,  1.21932677e+03, -2.22772410e+03,
#         4.83440789e+03,  1.81793276e+16,  1.37388173e+03,  3.57545838e+03,
#         2.17774297e+03, -8.50355626e+02, -2.17511807e+03, -1.79080363e+03,
#        -6.73148821e+03,  1.90672129e+04,  4.82174421e+03,  4.90926368e+03,
#         1.46157413e+03, -4.10162909e+02,  5.38635849e+03, -2.23683949e+03,
#        -1.77736629e+03,  1.13731122e+03,  4.31292066e+03, -3.78807242e+03,
#        -7.43560269e+01,  1.74894233e+03, -9.04510201e+03,  1.84016070e+03,
#        -4.18504900e+03, -1.56707850e+03, -9.46693843e+16,  2.31064464e+03,
#        -3.34590827e+16, -9.19501671e+16,  9.04967115e+16, -9.66090105e+02,
#        -2.96271226e+03,  5.94876135e+01, -2.89410742e+03, -3.51573473e+16,
#        -3.95195818e+16, -4.57421088e+15,  4.74601072e+16,  5.99953423e+03,
# ...

# %%
list(zip(lr.coef_,x1))
# Out:
# [(-699.8475494342393,
#   array([-1.43548658,  1.50830058, -0.02164599,  0.00423419, -0.62061571,
#           0.05862104,  0.2517623 , -1.37310708,  0.31847289,  0.        ,
#           0.60641989, -0.22612631,  0.14222402, -0.03733862, -0.02397949,
#           2.98549463, -0.54993041, -0.07516928, -0.53021681,  0.16823612,
#          -0.42156533, -0.48354421, -0.13457256, -0.21292688, -0.10489005,
#           0.36151839, -0.56223842,  0.67109308,  0.36932213, -0.55783596,
#          -0.34522056,  0.24582214,  0.59779033, -1.50698557, -0.70216091,
#           0.27491877, -0.28539162,  0.86440973,  0.03823936, -0.11908965,
#           1.39022978,  0.26750632,  0.29903648, -0.5418502 , -0.7936741 ,
#          -0.12541783, -1.07436276, -0.81611176, -0.23521255,  0.79308157,
#          -0.77013782, -1.08267897, -0.2098833 ,  0.80615443, -0.96558335,
#           0.26114554,  0.58850901,  0.13942599, -0.77486258, -0.04935633,
# ...

# %%
lr.intercept_
# Out:
# 181083.1187270502

# %%
lr.score(x1train,ytrain)
# Out:
# 0.8262809563860889

# %%
pred=lr.predict(x1test)
pred
# Out:
# array([192543.86872705, 198151.11872705,  62523.11872705, 210123.11872705,
#        301339.11872705, 208591.11872705,  89083.11872705, 145755.11872705,
#        192081.61872705, 196043.11872705, 173403.11872705, 204731.11872705,
#        156455.11872705, 159355.11872705, 259741.11872705, 282867.11872705,
#        187361.93122705, 184315.11872705, 183867.11872705, 121265.11872705,
#        230315.11872705, 328603.11872705, 334979.11872705, 197787.11872705,
#        191795.11872705, 149299.11872705, 194547.11872705, 200582.36872705,
#        126011.11872705, 141339.11872705, 136731.11872705, 118155.11872705,
#        374955.11872705, 131627.11872705, 108835.11872705, 157851.11872705,
#        184843.11872705, 137675.11872705, 111881.11872705, 126523.11872705,
#        103195.11872705, 118435.11872705,  90155.11872705, 145035.11872705,
#        219675.11872705,  77483.11872705, 402619.11872705, 150607.11872705,
# ...

# %%
print('Predicted values',pred)
# Out:
# Predicted values [192543.86872705 198151.11872705  62523.11872705 210123.11872705
#  301339.11872705 208591.11872705  89083.11872705 145755.11872705
#  192081.61872705 196043.11872705 173403.11872705 204731.11872705
#  156455.11872705 159355.11872705 259741.11872705 282867.11872705
#  187361.93122705 184315.11872705 183867.11872705 121265.11872705
#  230315.11872705 328603.11872705 334979.11872705 197787.11872705
#  191795.11872705 149299.11872705 194547.11872705 200582.36872705
#  126011.11872705 141339.11872705 136731.11872705 118155.11872705
#  374955.11872705 131627.11872705 108835.11872705 157851.11872705
#  184843.11872705 137675.11872705 111881.11872705 126523.11872705
#  103195.11872705 118435.11872705  90155.11872705 145035.11872705
#  219675.11872705  77483.11872705 402619.11872705 150607.11872705
#  222043.11872705  98235.11872705 142667.11872705 165243.11872705
#   84123.11872705  33339.11872705 196011.11872705 214651.11872705
# ...

# %%
preddf=pd.DataFrame(data=pred)
preddf
# Out:
#                  0
# 0    192543.868727
# 1    198151.118727
# 2     62523.118727
# 3    210123.118727
# 4    301339.118727
# ..             ...
# 346  169223.118727
# 347  139877.118727
# 348  119391.966115
# 349  164866.494525
# 350  148542.953121
#
# [351 rows x 1 columns]

# %%
lr.score(x1test,ytest)
# Out:
# 0.8362945830436889

# %%
print('R2 score::',r2_score(ytest,pred))
# Out:
# R2 score:: 0.8362945830436889

# %%
x2test=train_test_split(x2,test_size=0.30,random_state=55)

# %%
lm=LinearRegression()
lm.fit(x1train,ytrain)
lm.score(x1train,ytrain)
pred=lm.predict(x1test)
print('Predicted result:',pred)
print('actual',ytest)
# Out:
# Predicted result: [192543.86872705 198151.11872705  62523.11872705 210123.11872705
#  301339.11872705 208591.11872705  89083.11872705 145755.11872705
#  192081.61872705 196043.11872705 173403.11872705 204731.11872705
#  156455.11872705 159355.11872705 259741.11872705 282867.11872705
#  187361.93122705 184315.11872705 183867.11872705 121265.11872705
#  230315.11872705 328603.11872705 334979.11872705 197787.11872705
#  191795.11872705 149299.11872705 194547.11872705 200582.36872705
#  126011.11872705 141339.11872705 136731.11872705 118155.11872705
#  374955.11872705 131627.11872705 108835.11872705 157851.11872705
#  184843.11872705 137675.11872705 111881.11872705 126523.11872705
#  103195.11872705 118435.11872705  90155.11872705 145035.11872705
#  219675.11872705  77483.11872705 402619.11872705 150607.11872705
#  222043.11872705  98235.11872705 142667.11872705 165243.11872705
#   84123.11872705  33339.11872705 196011.11872705 214651.11872705
# ...

# %%
print('error:')
print(mean_squared_error(pred,ytest))
# Out:
# error:
# 982245045.9914232

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
ls=Lasso(alpha=0.0001)
parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x1train,ytrain)

print(clf.best_params_)
ls.fit(x1train,ytrain)
ls.score(x1train,ytrain)
pred_ls = ls.predict(x1test)

lss = r2_score(ytest,pred_ls)
lss
# Out:
# {'alpha': 10, 'random_state': 0}
# 0.8362262514292682

# %%
ls.coef_
# Out:
# array([ -673.69474396, -5329.35630565,    46.40688533,  2477.03692787,
#        -1240.17819444,  1492.12932064,  1214.60465799, -2214.55453193,
#         4913.02058549,     0.        ,  1291.62482062,  3637.27623681,
#         2175.57083964,  -819.15374217, -2164.90669364, -1816.49992196,
#        -6728.07309909, 19005.81646485,  4784.80129605,  4823.66630057,
#         1491.46334001,  -390.04283477,  5440.53829013, -2255.93558179,
#        -1759.78830299,  1109.27548926,  4252.02373598, -3799.116025  ,
#          -48.14225777,  1791.82099823, -9047.42263979,  1847.63733271,
#        -4127.2214973 , -1551.00133234,   728.1495455 ,  2284.79600273,
#          361.7629475 , -3303.39631219,  -606.71265798,  -939.62498214,
#        -2926.16034403,    42.22464339, -2884.59600393, 16225.02399485,
#        17548.67021216,   -67.20245497,  2921.76219232,  5980.97968405,
#          289.66467482,  3267.03735109,   384.02791338, -1343.52405844,
# ...

# %%
cv_score=cross_val_score(ls,x1,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.7460689204343324

# %%
parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
rd = Ridge()
clf = GridSearchCV(rd,parameters)
clf.fit(x1train,ytrain)

print(clf.best_params_)
rd=Ridge(alpha=0.0001)
rd.fit(x1train,ytrain)
rd.score(x1train,ytrain)
pred_rd = rd.predict(x1test)

rds = r2_score(ytest,pred_rd)
rds
# Out:
# {'alpha': 10, 'random_state': 0}
# 0.8361860390151863

# %%
rd.coef_
# Out:
# array([ -674.6462893 , -5327.69269939,    47.77771811,  2478.82064206,
#        -1243.42234923,  1492.5912884 ,  1215.85974911, -2215.55548276,
#         4915.99676867,     0.        ,  1292.60804249,  3640.16291837,
#         2177.0179624 ,  -820.3429918 , -2166.46251306, -1819.76265115,
#        -6732.99819256, 19004.00618809,  4786.42637649,  4835.03282132,
#         1491.75156191,  -392.65158124,  5440.25268509, -2255.71496415,
#        -1761.79808661,  1111.14414189,  4253.65740034, -3800.3917263 ,
#          -49.95784003,  1791.46173493, -9047.88544623,  1848.76818298,
#        -4128.30959619, -1551.7583243 ,  1319.60571033,  2288.68580856,
#          574.16595423, -2728.60147352, -1179.68925184,  -942.99467483,
#        -2926.31631623,    42.99643197, -2887.1369439 ,  8429.91680974,
#         8782.07698183, -1083.4257233 , 13453.01835478,  5983.68485295,
#          291.48942289,  3269.16812407,   384.6347312 , -1347.95026103,
# ...

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr.fit(x1train,ytrain)
enrpred=enr.predict(x1test)
print(enr.score(x1train,ytrain))
enrs=r2_score(ytest,enrpred)
enrs
enr.coef_
# Out:
# 0.826319029450397
# array([ -674.70660616, -5327.01796108,    48.1139788 ,  2478.64353702,
#        -1243.1255392 ,  1492.65744895,  1215.78887412, -2215.44381828,
#         4915.38344801,     0.        ,  1292.52776309,  3639.85925014,
#         2177.07330044,  -820.23172702, -2166.49055976, -1819.80271014,
#        -6731.81529099, 19001.33205354,  4785.80547953,  4833.90078967,
#         1492.32695529,  -392.34849188,  5440.13825084, -2255.77668493,
#        -1761.3235306 ,  1111.04628491,  4253.44231307, -3800.99334917,
#          -49.82473969,  1791.71051782, -9047.4416859 ,  1848.69654313,
#        -4128.13248493, -1551.89495672,  1558.1548669 ,  2288.26766849,
#          658.2454022 , -2496.54829526, -1406.76750533,  -942.80919436,
#        -2926.45107748,    43.16272756, -2886.70026284, 15789.10997699,
#        17054.03435776,  -125.88796074,  3518.213216  ,  5983.03238166,
#          291.41080803,  3269.61042843,   385.07487974, -1347.82188908,
# ...

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel = 'linear')
svr.fit(x1train,ytrain)
svr.score(x1train,ytrain)
pred_y=svr.predict(x1test)
svr = SVR(kernel = 'poly')
svr.fit(x1train,ytrain)
svr.score(x1train,ytrain)
pred_y=svr.predict(x1test)
svr = SVR(kernel = 'rbf')
svr.fit(x1train,ytrain)
svr.score(x1train,ytrain)
pred_y=svr.predict(x1test)

# %%
from sklearn.svm import SVR
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x1train,ytrain)
    print(sv.score(x1train,ytrain))
# Out:
# 0.09317717026654182
# -0.04878640341523788
# -0.04853507272578517

# %%
from sklearn import preprocessing
from sklearn import utils

lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(ytrain)

print(utils.multiclass.type_of_target(ytrain))

print(utils.multiclass.type_of_target(ytrain.astype('int')))

print(utils.multiclass.type_of_target(encoded))
# Out:
# multiclass
# multiclass
# multiclass

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x1train,ytrain)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(x1train, ytrain)
rf.score(x1train, ytrain)
pred_decision = rf.predict(x1test)

rfs = r2_score(ytest,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,x1,y,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 84.99714707106574
# Cross Val Score: 84.01881905523453

# %%
print('Mean absolute error::',mean_absolute_error(ytest,pred)) 
print('Mean squared error::',mean_squared_error(ytest,pred))
print('Root mean square::',np.sqrt(mean_squared_error(ytest,pred)))
# Out:
# Mean absolute error:: 22084.355285107293
# Mean squared error:: 982245045.9914232
# Root mean square:: 31340.788854006583

# %%
import pickle
filename = 'housepriceprediction.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('housepriceprediction.pkl', 'rb'))
result = loaded_model.score(x1test, ytest)
print(result)
# Out:
# 0.8499714707106574

# %%
conclusion=pd.DataFrame([loaded_model.predict(x1test)[:],pred_decision[:]],index=["Predicted","Orginal"])

# %%
conclusion
# Out:
#                  0          1          2         3          4          5    \
# Predicted  202678.56  204794.45  104670.94  177780.8  378832.06  205939.65
# Orginal    202678.56  204794.45  104670.94  177780.8  378832.06  205939.65
#
#                  6          7          8          9    ...       341  \
# Predicted  119796.58  139930.27  178596.36  162451.36  ...  129436.1
# Orginal    119796.58  139930.27  178596.36  162451.36  ...  129436.1
#
#                  342        343        344        345        346        347  \
# Predicted  360724.14  362364.87  145204.39  158955.82  119507.08  161769.22
# Orginal    360724.14  362364.87  145204.39  158955.82  119507.08  161769.22
#
#                  348       349        350
# Predicted  146262.35  181716.0  117182.66
# Orginal    146262.35  181716.0  117182.66
#
# [2 rows x 351 columns]
